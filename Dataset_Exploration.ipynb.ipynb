# %%
#How many rows and columns are contained in the datasets?
The dataset has 20,000 rows and 7 columns

# %%
#What datatypes are contained in the dataset?
The dataset has : Integers, String and Boolean

# %%
#Is the dataset complete?
The dataset has ~5% missing values in the source and authors column
